# %% [markdown]
# Internship Program at the Sparks Foundation for the month of Dcember 2020

# %% [markdown]
# Task 3: Exploratory Data Analysis - Retail

# %% [markdown]
# # Importing Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Importing Data set

# %%
store=pd.read_csv("D:\python\SampleSuperstore.csv")

# %%
store.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# Finding null values to eliminate

# %%
store.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# # Data Visualisation

# %%
#to calculate the count of column: segment
seg=store.Segment.value_counts().reset_index()
seg.columns=("Segment","counts")
seg
# Out:
#        Segment  counts
# 0     Consumer    5191
# 1    Corporate    3020
# 2  Home Office    1783

# %% [markdown]
# Pie chart to display domination of Segments

# %%
#Pie Chart 
plt.pie(x="counts",labels="Segment",data=seg,radius=2, autopct="%.2f",pctdistance=0.6)
# Out:
# ([<matplotlib.patches.Wedge at 0x288d1026ac8>,
# ...
#  [Text(-0.13408036713364035, 2.1959103932422446, 'Consumer'),
#   Text(-1.0537686579632295, -1.9312098838537397, 'Corporate'),
#   Text(1.8633972391176687, -1.1695087555245793, 'Home Office')],
#  [Text(-0.07313474570925836, 1.1977693054048604, '51.94'),
#   Text(-0.5747829043435797, -1.053387209374767, '30.22'),
#   Text(1.0163984940641828, -0.6379138666497705, '17.84')])

# %% [markdown]
# In the category of Segment the percentage of consumers is greater

# %% [markdown]
# # To calculate the count of each region and to asses the contribution from each region.

# %% [markdown]
# reg=store.Region.value_counts().reset_index()
# reg.columns=("Region","counts")
# reg

# %% [markdown]
# Pie chart for better understanding of domination of regions

# %%
#proportion of Regions
plt.pie(x="counts",labels="Region",data=reg,radius=2, autopct="%.2f",pctdistance=0.6,colors=("blue","yellow","grey","green"))
# Out:
# ([<matplotlib.patches.Wedge at 0x1feaf98aa88>,
# ...
#  [Text(1.175944701445042, 1.8593423727606844, 'West'),
#   Text(-2.1407459458509597, 0.507155592814159, 'East'),
#   Text(-0.3893642795444306, -2.1652702967100543, 'Central'),
#   Text(1.920849673485126, -1.0725374267931564, 'South')],
#  [Text(0.6414243826063865, 1.014186748778555, '32.05'),
#   Text(-1.1676796068277961, 0.2766303233531776, '28.50'),
#   Text(-0.21238051611514394, -1.1810565254782113, '23.24'),
#   Text(1.0477361855373413, -0.585020414614449, '16.21')])

# %% [markdown]
# # To find out the respective columns related to high sales

# %%
sale_high=store[store["Sales"]>3000]
sale_high
# Out:
#            Ship Mode      Segment        Country           City  \
# 27    Standard Class     Consumer  United States   Philadelphia
# 165   Standard Class     Consumer  United States    San Antonio
# 251   Standard Class     Consumer  United States      San Diego
# 262     Second Class    Corporate  United States        Houston
# 318   Standard Class  Home Office  United States  New York City
# ...              ...          ...            ...            ...
# 9639    Second Class     Consumer  United States        Concord
# 9649  Standard Class     Consumer  United States    Los Angeles
# 9660  Standard Class  Home Office  United States  Santa Barbara
# 9741  Standard Class    Corporate  United States     Burlington
# 9857  Standard Class    Corporate  United States        Seattle
#
#                State  Postal Code   Region    Category Sub-Category     Sales  \
# 27      Pennsylvania        19140     East   Furniture    Bookcases  3083.430
# ...

# %% [markdown]
# Here we take a margin value of 3000, so that region/state with highest sales can be found out easily.

# %% [markdown]
# # visualising data with the help of a bar plot to find the states with high sales

# %%
sns.barplot(y=sale_high["State"],x=sale_high["Sales"],data=sale)

# %% [markdown]
# Highest value of sales

# %%
store.Sales.max()
# Out:
# 22638.48

# %% [markdown]
# # Displaying the lowest sales data

# %%
sale_lowest=store[store["Sales"]<1]
sale_lowest
# Out:
#            Ship Mode      Segment        Country           City         State  \
# 2106        Same Day    Corporate  United States       Mesquite         Texas
# 2761     First Class  Home Office  United States  San Francisco    California
# 4101  Standard Class     Consumer  United States        Houston         Texas
# 4711        Same Day     Consumer  United States   Philadelphia  Pennsylvania
# 7548  Standard Class    Corporate  United States     Huntsville         Texas
# 8033     First Class     Consumer  United States        Houston         Texas
# 8658  Standard Class    Corporate  United States        Chicago      Illinois
# 9292        Same Day    Corporate  United States           Waco         Texas
#
#       Postal Code   Region         Category Sub-Category  Sales  Quantity  \
# 2106        75150  Central  Office Supplies      Binders  0.876         1
# 2761        94110     West       Technology  Accessories  0.990         1
# ...

# %% [markdown]
# # Barplot to display the states with lowest sales data

# %%
sns.barplot(y=sale_lowest["State"],x=sale_lowest["Sales"],data=sale_lowest)

# %% [markdown]
# # Displaying the data for Low Profit

# %%
low_profit=store[store["Profit"]<1]
low_profit
# Out:
#            Ship Mode      Segment        Country             City  \
# 3     Standard Class     Consumer  United States  Fort Lauderdale
# 14    Standard Class  Home Office  United States       Fort Worth
# 15    Standard Class  Home Office  United States       Fort Worth
# 23      Second Class     Consumer  United States     Philadelphia
# 27    Standard Class     Consumer  United States     Philadelphia
# ...              ...          ...            ...              ...
# 9931  Standard Class     Consumer  United States   San Bernardino
# 9937    Second Class    Corporate  United States      Los Angeles
# 9944    Second Class  Home Office  United States          Seattle
# 9962     First Class  Home Office  United States          Houston
# 9977  Standard Class  Home Office  United States      Los Angeles
#
#              State  Postal Code   Region         Category Sub-Category  \
# 3          Florida        33311    South        Furniture       Tables
# ...

# %% [markdown]
# *By this evaluation the weak areas having lower profit can be found out

# %% [markdown]
# Inference:
#     The above evaluation of data clearly give an idea of weak points which are to be sorted out for improving the buisness.
#     With the help of pie chart, Boxplots etc the data is legible and the user finds it easy to find out the weak and strong areas by refering those charts and plots.
#     The state with higher sales data and lower sales data is shown in this project.
#     In the last section the profit margin is shown, value less than 1 is always termed as a loss, and those with low profit has been found which will be helpful for buisness analysis.
